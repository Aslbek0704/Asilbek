# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("ds.csv",index_col=0)

# %% [markdown]
# # Indeks(['tajriba_darajasi', 'ish_turi', 'ish_unvoni', 'ish haqi',
#  # 'maosh_valyutasi', 'usdda_ish haqi', 'xodimning_yashash joyi',
#  # 'uzoq_nisbat', 'kompaniya_joylashuvi', 'kompaniya_hajmi'],

# %%
df.head()
# Out:
#           experience_level employment_type                 job_title  salary  \
# work_year
# 2023                    SE              FT  Principal Data Scientist   80000
# 2023                    MI              CT               ML Engineer   30000
# 2023                    MI              CT               ML Engineer   25500
# 2023                    SE              FT            Data Scientist  175000
# 2023                    SE              FT            Data Scientist  120000
#
#           salary_currency  salary_in_usd employee_residence  remote_ratio  \
# work_year
# 2023                  EUR          85847                 ES           100
# 2023                  USD          30000                 US           100
# 2023                  USD          25500                 US           100
# 2023                  USD         175000                 CA           100
# 2023                  USD         120000                 CA           100
#
# ...

# %%
sns.countplot(x="employee_residence",data=df)

plt.show()

# %%
df.columns
# Out:
# Index(['experience_level', 'employment_type', 'job_title', 'salary',
#        'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
sns.scatterplot(x="company_location",y="salary",data=df)
plt.show()

# %%
sns.set_style("whitegrid")

sns.catplot(x="salary_in_usd",
            data=df,
            hue="salary",
            kind="point")
plt.show()
