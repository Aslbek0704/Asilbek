# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
url="https://assets.datacamp.com/production/repositories/2210/datasets/794e0759b73a2d80baa5d8fb88636a47965139d3/college_datav3.csv"
df=pd.read_csv(url)
df.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6702 entries, 0 to 6701
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INSTNM            6702 non-null   object
#  1   OPEID             6702 non-null   int64
#  2   REGION            6702 non-null   int64
#  3   SAT_AVG_ALL       1387 non-null   float64
#  4   PCTPELL           6066 non-null   float64
#  5   PCTFLOAN          6066 non-null   float64
#  6   ADM_RATE_ALL      2180 non-null   float64
#  7   UG                4367 non-null   float64
#  8   AVGFACSAL         4104 non-null   float64
#  9   COMPL_RPY_5YR_RT  5708 non-null   object
#  10  DEBT_MDN          6681 non-null   object
#  11  MEDIAN_HH_INC     4993 non-null   object
#  12  ICLEVEL           6702 non-null   int64
#  13  HIGHDEG           6702 non-null   int64
#  14  CONTROL           6702 non-null   int64
#  15  WOMENONLY         6368 non-null   float64
# ...

# %%
df.describe()
# Out:
#               OPEID       REGION  SAT_AVG_ALL      PCTPELL     PCTFLOAN  \
# count  6.702000e+03  6702.000000  1387.000000  6066.000000  6066.000000
# mean   1.788528e+06     4.602954  1065.332372     0.502318     0.490676
# std    3.304120e+06     2.177145   134.879236     0.220404     0.279644
# min    1.002000e+05     0.000000   708.000000     0.000000     0.000000
# 25%    3.188250e+05     3.000000   981.500000     0.338525     0.285725
# 50%    1.005302e+06     5.000000  1048.000000     0.483850     0.548200
# 75%    2.598900e+06     6.000000  1127.000000     0.666700     0.704500
# max    8.209884e+07     9.000000  1544.000000     1.000000     1.000000
#
#        ADM_RATE_ALL            UG     AVGFACSAL      ICLEVEL      HIGHDEG  \
# count   2180.000000   4367.000000   4104.000000  6702.000000  6702.000000
# mean       0.681821   2945.242501   6451.342105     1.811698     2.276783
# std        0.204033   4974.178446   2376.043146     0.817686     1.324162
# ...

# %% [markdown]
# # Columnslar boyicha NaN qiymatlar foizlarda

# %%
df.isnull().mean()*100
# Out:
# INSTNM               0.000000
# OPEID                0.000000
# REGION               0.000000
# SAT_AVG_ALL         79.304685
# PCTPELL              9.489705
# PCTFLOAN             9.489705
# ADM_RATE_ALL        67.472396
# UG                  34.840346
# AVGFACSAL           38.764548
# COMPL_RPY_5YR_RT    14.831394
# DEBT_MDN             0.313339
# MEDIAN_HH_INC       25.499851
# ICLEVEL              0.000000
# HIGHDEG              0.000000
# CONTROL              0.000000
# WOMENONLY            4.983587
# MENONLY              4.983587
# LOCALE               4.983587
# Tuition             14.428529
# Degree_Type          0.000000
# Ownership            0.000000
# Regions              0.000000
# Locales              4.983587
# Locale_Short         5.028350
# dtype: float64

# %% [markdown]
# # NaN qiymatlar soni 50% dan oshganlarni olib tawlaymz

# %%
df=df.drop('SAT_AVG_ALL',axis=1)
df=df.drop('ADM_RATE_ALL', axis=1)

# %%
df.isnull().mean()*100
# Out:
# INSTNM               0.000000
# OPEID                0.000000
# REGION               0.000000
# PCTPELL              9.489705
# PCTFLOAN             9.489705
# UG                  34.840346
# AVGFACSAL           38.764548
# COMPL_RPY_5YR_RT    14.831394
# DEBT_MDN             0.313339
# MEDIAN_HH_INC       25.499851
# ICLEVEL              0.000000
# HIGHDEG              0.000000
# CONTROL              0.000000
# WOMENONLY            4.983587
# MENONLY              4.983587
# LOCALE               4.983587
# Tuition             14.428529
# Degree_Type          0.000000
# Ownership            0.000000
# Regions              0.000000
# Locales              4.983587
# Locale_Short         5.028350
# dtype: float64

# %% [markdown]
# # Barcha columns ni NaN qiymatlarni tozalash

# %%
a=df['PCTPELL'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['PCTPELL'].transform('median')
df['PCTPELL'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="PCTPELL", ax=ax[0],kde=True)
sns.histplot(df, x=df['PCTPELL'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\4180709990.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PCTPELL'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %%
a=df['PCTFLOAN']

mean_values = df.groupby(['REGION', 'Ownership'])['PCTFLOAN'].transform('median')
df['PCTFLOAN'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, ax=ax[0],kde=True)
sns.histplot(df, x=df['PCTFLOAN'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %%
a=df['UG'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['UG'].transform('median')
df['UG'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="UG", ax=ax[0],kde=True)
sns.histplot(df, x=df['UG'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\3207740845.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['UG'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %%
a=df['AVGFACSAL'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['AVGFACSAL'].transform('median')
df['AVGFACSAL'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="AVGFACSAL", ax=ax[0],kde=True)
sns.histplot(df, x=df['AVGFACSAL'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\4092312722.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AVGFACSAL'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %%
a=df['WOMENONLY'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['WOMENONLY'].transform('median')
df['WOMENONLY'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="WOMENONLY", ax=ax[0],kde=True)
sns.histplot(df, x=df['WOMENONLY'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\739950851.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WOMENONLY'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %%
a=df['MENONLY'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['MENONLY'].transform('median')
df['MENONLY'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="MENONLY", ax=ax[0],kde=True)
sns.histplot(df, x=df['MENONLY'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\1149778330.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MENONLY'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %%
a=df['LOCALE'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['LOCALE'].transform('median')
df['LOCALE'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="LOCALE", ax=ax[0],kde=True)
sns.histplot(df, x=df['LOCALE'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\2706025654.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LOCALE'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %%
a=df['Tuition'].to_frame()

mean_values = df.groupby(['REGION', 'Ownership'])['Tuition'].transform('median')
df['Tuition'].fillna(mean_values, inplace=True)

fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.histplot(a, x="Tuition", ax=ax[0],kde=True)
sns.histplot(df, x=df['Tuition'],ax=ax[1],kde=True,color='r')
ax[0].set_title("Before")
ax[1].set_title("After")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16684\1060067040.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Tuition'].fillna(mean_values, inplace=True)
# Text(0.5, 1.0, 'After')

# %% [markdown]
# # Har bir HIGHDEG boyicha Tuition ni aniqlash har biri alohida boxplotda chiqadi

# %%
g=sns.FacetGrid(df, col="HIGHDEG")
g.map(sns.boxplot, 'Tuition')
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df.columns
# Out:
# Index(['INSTNM', 'OPEID', 'REGION', 'PCTPELL', 'PCTFLOAN', 'UG', 'AVGFACSAL',
#        'COMPL_RPY_5YR_RT', 'DEBT_MDN', 'MEDIAN_HH_INC', 'ICLEVEL', 'HIGHDEG',
#        'CONTROL', 'WOMENONLY', 'MENONLY', 'LOCALE', 'Tuition', 'Degree_Type',
#        'Ownership', 'Regions', 'Locales', 'Locale_Short'],
#       dtype='object')

# %%
g=sns.PairGrid(df, vars=['REGION', 'Tuition'])
g.map(sns.scatterplot
      )

# %% [markdown]
# # Pair plot orqali ma'lumotlar to'plamidagi barcha o'zgaruvchilar orasidagi bog'liqlik va munosabatlarni bir qarashda ko'rish mumkin. Bu, ayniqsa, ko'p miqdordagi o'zgaruvchilarni tahlil qilishda foydalidir.

# %%
sns.pairplot(df)

# %% [markdown]
# # Joint plot bilan siz ikkita o'zgaruvchi orasidagi bog'liqlikni, ularning taqsimotini va qiyosini bir grafikka jamlash orqali ko'rishingiz mumkin.

# %%
sns.jointplot(x='Locales', y='Tuition', data=df)

# %%
df.columns
# Out:
# Index(['INSTNM', 'OPEID', 'REGION', 'PCTPELL', 'PCTFLOAN', 'UG', 'AVGFACSAL',
#        'COMPL_RPY_5YR_RT', 'DEBT_MDN', 'MEDIAN_HH_INC', 'ICLEVEL', 'HIGHDEG',
#        'CONTROL', 'WOMENONLY', 'MENONLY', 'LOCALE', 'Tuition', 'Degree_Type',
#        'Ownership', 'Regions', 'Locales', 'Locale_Short'],
#       dtype='object')
