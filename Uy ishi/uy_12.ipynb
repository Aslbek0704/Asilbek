# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df=df.drop(columns=["test preparation course"])
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      math score  reading score  writing score
# 0            72             72             74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   math score                   1000 non-null   int64
#  5   reading score                1000 non-null   int64
#  6   writing score                1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %%
sns.histplot(x=df["math score"], kde=True)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
df["math score"].describe
# Out:
# <bound method NDFrame.describe of 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64>

# %%
x=df["writing score"]

# %% [markdown]
# # math_score ni normallashtirish

# %%
df["Normalizition"]=(x-x.mean())/x.std()
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#    math score  reading score  writing score  Normalizition
# 0          72             72             74       0.391296
# 1          69             90             88       1.312612
# 2          90             95             93       1.641653
# 3          47             57             44      -1.582952
# 4          76             78             75       0.457104

# %% [markdown]
# # Normallashtirishdan oldin va keyingi grafiklari

# %%
fig , ax=plt.subplots(1,2 , figsize=(12,5))
sns.histplot(df["writing score"],ax=ax[0],kde=True)
sns.histplot(df["Normalizition"],ax=ax[1],kde=True,color="y")
# Out:
# <Axes: xlabel='Normalizition', ylabel='Count'>

# %% [markdown]
# # Writing score ni 0 va 1 oraligiga olib kelish yani - ( min-max normalization)

# %%
df["Min_Max"]=(x-x.min())/(x.max()-x.min())
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#    math score  reading score  writing score  Normalizition   Min_Max
# 0          72             72             74       0.391296  0.711111
# 1          69             90             88       1.312612  0.866667
# 2          90             95             93       1.641653  0.922222
# 3          47             57             44      -1.582952  0.377778
# 4          76             78             75       0.457104  0.722222

# %%
fig , ax=plt.subplots(1,2 , figsize=(12,5))
sns.histplot(df["writing score"],ax=ax[0],kde=True)
sns.histplot(df["Min_Max"],ax=ax[1],kde=True,color="y")
# Out:
# <Axes: xlabel='Min_Max', ylabel='Count'>

# %%
df["Quantile"]=(x-x.median())/(x.quantile(0.75)-x.quantile(0.25))
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#    math score  reading score  writing score  Normalizition   Min_Max  Quantile
# 0          72             72             74       0.391296  0.711111  0.235294
# 1          69             90             88       1.312612  0.866667  0.894118
# 2          90             95             93       1.641653  0.922222  1.129412
# 3          47             57             44      -1.582952  0.377778 -1.176471
# 4          76             78             75       0.457104  0.722222  0.282353

# %%
fig , ax=plt.subplots(1,2 , figsize=(12,5))
sns.histplot(df["writing score"],ax=ax[0],kde=True)
sns.histplot(df["Quantile"],ax=ax[1],kde=True,color="y")
# Out:
# <Axes: xlabel='Quantile', ylabel='Count'>

# %% [markdown]
# Hammasi birida

# %%
fig , ax=plt.subplots(3,2 , figsize=(12,20))

sns.histplot(df["writing score"],ax=ax[0,0],kde=True)
sns.histplot(df["Normalizition"],ax=ax[0,1],kde=True,color="y")

sns.histplot(df["writing score"],ax=ax[1,0],kde=True)
sns.histplot(df["Min_Max"],ax=ax[1,1],kde=True,color="y")

sns.histplot(df["writing score"],ax=ax[2,0],kde=True)
sns.histplot(df["Quantile"],ax=ax[2,1],kde=True,color="y")
# Out:
# <Axes: xlabel='Quantile', ylabel='Count'>
