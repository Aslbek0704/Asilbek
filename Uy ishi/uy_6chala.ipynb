# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("Sales.csv" , index_col=0)
df
# Out:
#                       Date Product Category  \
# Transaction ID
# 10001           2024-01-01      Electronics
# 10002           2024-01-02  Home Appliances
# 10003           2024-01-03         Clothing
# 10004           2024-01-04            Books
# 10005           2024-01-05  Beauty Products
# ...                    ...              ...
# 10214           2024-08-01            Books
# 10215           2024-08-02  Beauty Products
# 10216           2024-08-03           Sports
# 10217           2024-08-04      Electronics
# 10218           2024-08-05  Home Appliances
#
#                                                     Product Name  Units Sold  \
# Transaction ID
# 10001                                              iPhone 14 Pro           2
# 10002                                           Dyson V11 Vacuum           1
# 10003                                           Levi's 501 Jeans           3
# 10004                                          The Da Vinci Code           4
# ...

# %% [markdown]
# # Qayerlarga koproq sotiladi ? (Bar va Pie korinishlarda)

# %%
Regionls=df["Region"].unique()
count=df["Region"].value_counts()

fig , ax=plt.subplots()
ax.bar(Regionls, count, label="Region")
ax.set_title('Bar diagramma')
plt.legend()
plt.show()

# %%
Regionls=df["Region"].unique()
count=df["Region"].value_counts()

fig , ax=plt.subplots()
ax.pie(count, labels=Regionls, explode=(0,0.1,0), autopct='%1.1f%%')
ax.axis('equal')
ax.set_title('Pie diagramma')
plt.show()

# %% [markdown]
# # Amerikani pishloq , sut va bowqa mahsulotlarni iwlab chiqarishi State boyicha

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("cheese.csv" , index_col=0)
df
# Out:
#      Period Geo_Level  State_ANSI  Commodity_ID Domain          Value
# Year
# 2023    APR     STATE         6.0             6  TOTAL    208,807,000
# 2023    APR     STATE        16.0             6  TOTAL     86,452,000
# 2023    APR     STATE        17.0             6  TOTAL      5,068,000
# 2023    APR     STATE        19.0             6  TOTAL     31,512,000
# 2023    APR     STATE        27.0             6  TOTAL     69,728,000
# ...     ...       ...         ...           ...    ...            ...
# 2020   YEAR     STATE        39.0             6  TOTAL    245,118,000
# 2020   YEAR     STATE         NaN             6  TOTAL  2,533,667,000
# 2020   YEAR     STATE        42.0             6  TOTAL    435,837,000
# 2020   YEAR     STATE        50.0             6  TOTAL    144,462,000
# 2020   YEAR     STATE        55.0             6  TOTAL  3,389,620,000
#
# [589 rows x 6 columns]

# %%
# # 1. Period (davr) bo'yicha qiymatlar taqsimoti
# period_counts = df['Period'].value_counts()
# fig, ax = plt.subplots()
# ax.bar(period_counts.index, period_counts.values)
# ax.set_xlabel('Period')
# ax.set_ylabel('Qiymatlar soni')
# ax.set_title('Period bo\'yicha qiymatlar taqsimoti')
# plt.show()

# # 2. Geo_Level (geografik daraja) bo'yicha qiymatlar taqsimoti
# geo_counts = df['Geo_Level'].value_counts()
# fig, ax = plt.subplots()
# ax.bar(geo_counts.index, geo_counts.values)
# ax.set_xlabel('Geo Level')
# ax.set_ylabel('Qiymatlar soni')
# ax.set_title('Geo_Level bo\'yicha qiymatlar taqsimoti')
# plt.show()

# 3. State_ANSI (shtat kodi) bo'yicha qiymatlar taqsimoti
state_counts = df['State_ANSI'].value_counts()
fig, ax = plt.subplots()
ax.bar(state_counts.index, state_counts.values)
ax.set_xlabel('State ANSI')
ax.set_ylabel('Qiymatlar soni')
ax.set_title('State_ANSI bo\'yicha qiymatlar taqsimoti')
plt.show()

# 4. Commodity_ID (mahsulot identifikatori) bo'yicha qiymatlar taqsimoti
commodity_counts = df['Commodity_ID'].value_counts()
fig, ax = plt.subplots()
ax.bar(commodity_counts.index, commodity_counts.values)
ax.set_xlabel('Commodity ID')
ax.set_ylabel('Qiymatlar soni')
ax.set_title('Commodity_ID bo\'yicha qiymatlar taqsimoti')
plt.show()

# 5. Domain (soha) bo'yicha qiymatlar taqsimoti
domain_counts = df['Domain'].value_counts()
fig, ax = plt.subplots()
ax.bar(domain_counts, domain_counts.values)
ax.set_xlabel('Domain')
ax.set_ylabel('Qiymatlar soni')
ax.set_title('Domain bo\'yicha qiymatlar taqsimoti')
plt.show()

# 6. Umumiy qiymatlar taqsimoti
fig, ax = plt.subplots()
ax.hist(df['Value'], bins=10, color='purple')
ax.set_xlabel('Qiymat')
ax.set_ylabel('Frekans')
ax.set_title('Umumiy qiymatlar taqsimoti')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV faylni yuklab olish
df = pd.read_csv('data.csv')

# 2022 yili uchun o'rtacha qiymatlarni hisoblash
df['Average 2022'] = df[['Jan 2022', 'Feb 2022', 'Mar 2022', 'Apr 2022', 'May 2022', 'Jun 2022',
                         'Jul 2022', 'Aug 2022', 'Sep 2022', 'Oct 2022', 'Nov 2022', 'Dec 2022']].mean(axis=1)

# Grafikni tayyorlash
plt.figure(figsize=(10, 6))
plt.bar(df['State'], df['Average 2022'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Average Value for 2022')
plt.title('Average Values for 2022 by State')
plt.xticks(rotation=45)
plt.tight_layout()

# Grafikni ko'rsatish
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 5
#       2 import matplotlib.pyplot as plt
#       4 # CSV faylni yuklab olish
# ----> 5 df = pd.read_csv('data.csv')
#       7 # 2022 yili uchun o'rtacha qiymatlarni hisoblash
#       8 df['Average 2022'] = df[['Jan 2022', 'Feb 2022', 'Mar 2022', 'Apr 2022', 'May 2022', 'Jun 2022',
#       9                          'Jul 2022', 'Aug 2022', 'Sep 2022', 'Oct 2022', 'Nov 2022', 'Dec 2022']].mean(axis=1)
#
# ...
